# %%
import json
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
from model import Dfembeding
from sklearn.kernel_ridge import KernelRidge
import torch
from PIL import Image
from utils import *
import csv
import torch.utils.data as data
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 from sklearn.metrics import mean_squared_error, mean_absolute_error
#       3 import numpy as np
# ----> 4 from model import Dfembeding
#       5 from sklearn.kernel_ridge import KernelRidge
#       6 import torch
#
# File e:\assignment (9th sem)\CAP II\Body Fat Analysis System\2DImage2BMI-main\model.py:1
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'torch'
